# %% [markdown]
# # Importing the required modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import spacy

# %% [markdown]
# # Reading the dataset

# %%
curr = pd.read_csv("../data/curriculum.csv")

# %% [markdown]
# # Glimpse into the dataset

# %%
curr.head()
# Out:
#                                              Courses             Topic  \
# 0                               Python for Everybody          Intro CS
# 1  Introduction to Computer Science and Programmi...          Intro CS
# 2                          How to Code - Simple Data  Core Programming
# 3                         How to Code - Complex Data  Core Programming
# 4                      Programming Languages, Part A  Core Programming
#
#    Duration           Effort  Total Hours Lower Bound  Start Date  \
# 0  10 weeks    10 hours/week                      100  28-07-2022
# 1   9 weeks    15 hours/week                      135  01-09-2022
# 2   7 weeks  8-10 hours/week                       56  18-10-2022
# 3   6 weeks  8-10 hours/week                       48  06-11-2022
# 4   5 weeks   4-8 hours/week                       20  23-11-2022
#
#   End Date Estimate Lower Bound  Total Hours Upper Bound Start Date.1  \
# 0                    01-09-2022                      100   28-07-2022
# 1                    18-10-2022                      135   01-09-2022
# 2                    06-11-2022                       70   18-10-2022
# 3                    23-11-2022                       60   11-11-2022
# 4                    30-11-2022                       40   02-12-2022
#
#   End Date Estimate Upper Bound  Actual End Date  \
# 0                    01-09-2022              NaN
# 1                    18-10-2022              NaN
# 2                    11-11-2022              NaN
# 3                    02-12-2022              NaN
# 4                    16-12-2022              NaN
#
#                    Prerequisites
# 0                              -
# 1            high school algebra
# 2                              -
# 3       How to Code: Simple Data
# 4  How to Code (Hear instructor)

# %%
curr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Courses                        43 non-null     object
#  1   Topic                          43 non-null     object
#  2   Duration                       42 non-null     object
#  3   Effort                         42 non-null     object
#  4   Total Hours Lower Bound        43 non-null     int64
#  5   Start Date                     43 non-null     object
#  6   End Date Estimate Lower Bound  43 non-null     object
#  7   Total Hours Upper Bound        43 non-null     int64
#  8   Start Date.1                   43 non-null     object
#  9   End Date Estimate Upper Bound  43 non-null     object
#  10  Actual End Date                0 non-null      float64
#  11  Prerequisites                  42 non-null     object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 4.2+ KB

# %% [markdown]
# # Alloting course codes to each course

# %%
def get_course_code(row):
    topic = row[1].title()
    topic = "".join(re.findall("[A-Z]",topic))
    courses_in_topic = list(curr[curr["Topic"] == row[1]]["Courses"])
    course_code = str(courses_in_topic.index(row[0]) + 1).rjust(3,"0")
    return topic + course_code

# %%
curr["Course Code"] = curr.apply(get_course_code,axis=1)

# %%
df.head()
# Out:
#                                    Python for Everybody  \
# Prerequisite
# any programming language                       0.448595
#  Mathematics for Computer Science              0.448595
# C++                                            0.281555
#  Java                                          0.281555
#  linear algebra                                0.281555
#
#                                    Introduction to Computer Science and Programming using Python  \
# Prerequisite
# any programming language                                                    0.595221
#  Mathematics for Computer Science                                           0.595221
# C++                                                                         0.212375
#  Java                                                                       0.212375
#  linear algebra                                                             0.212375
#
#                                    How to Code - Simple Data  \
# Prerequisite
# any programming language                            0.441982
#  Mathematics for Computer Science                   0.441982
# C++                                                 0.319161
#  Java                                               0.319161
#  linear algebra                                     0.319161
#
#                                    How to Code - Complex Data  \
# Prerequisite
# any programming language                             0.499089
#  Mathematics for Computer Science                    0.499089
# C++                                                  0.284144
#  Java                                                0.284144
#  linear algebra                                      0.284144
#
#                                    Programming Languages, Part A  \
# Prerequisite
# any programming language                                0.660203
#  Mathematics for Computer Science                       0.660203
# C++                                                     0.507478
#  Java                                                   0.507478
#  linear algebra                                         0.507478
#
#                                    Programming Languages, Part B  \
# Prerequisite
# any programming language                                0.659250
#  Mathematics for Computer Science                       0.659250
# C++                                                     0.478266
#  Java                                                   0.478266
#  linear algebra                                         0.478266
#
#                                    Programming Languages, Part C  \
# Prerequisite
# any programming language                                0.644460
#  Mathematics for Computer Science                       0.644460
# C++                                                     0.528526
#  Java                                                   0.528526
#  linear algebra                                         0.528526
#
#                                    Object-Oriented Design  Design Patterns  \
# Prerequisite
# any programming language                         0.406581         0.524441
#  Mathematics for Computer Science                0.406581         0.524441
# C++                                              0.074031         0.293981
#  Java                                            0.074031         0.293981
#  linear algebra                                  0.074031         0.293981
#
#                                    Software Architecture  ...  Core Ethics  \
# Prerequisite                                              ...
# any programming language                        0.612727  ...     0.519370
#  Mathematics for Computer Science               0.612727  ...     0.519370
# C++                                             0.356474  ...     0.368729
#  Java                                           0.356474  ...     0.368729
#  linear algebra                                 0.356474  ...     0.368729
#
#                                    Core Ethics.1  Core Ethics.2  \
# Prerequisite
# any programming language                0.519370       0.519370
#  Mathematics for Computer Science       0.519370       0.519370
# C++                                     0.368729       0.368729
#  Java                                   0.368729       0.368729
#  linear algebra                         0.368729       0.368729
#
#                                    Advanced Programming  \
# Prerequisite
# any programming language                       0.552126
#  Mathematics for Computer Science              0.552126
# C++                                            0.189097
#  Java                                          0.189097
#  linear algebra                                0.189097
#
#                                    Advanced Programming.1  \
# Prerequisite
# any programming language                         0.552126
#  Mathematics for Computer Science                0.552126
# C++                                              0.189097
#  Java                                            0.189097
#  linear algebra                                  0.189097
#
#                                    Advanced Programming.2  \
# Prerequisite
# any programming language                         0.552126
#  Mathematics for Computer Science                0.552126
# C++                                              0.189097
#  Java                                            0.189097
#  linear algebra                                  0.189097
#
#                                    Advanced Programming.3  \
# Prerequisite
# any programming language                         0.552126
#  Mathematics for Computer Science                0.552126
# C++                                              0.189097
#  Java                                            0.189097
#  linear algebra                                  0.189097
#
#                                    Advanced Programming.4  \
# Prerequisite
# any programming language                         0.552126
#  Mathematics for Computer Science                0.552126
# C++                                              0.189097
#  Java                                            0.189097
#  linear algebra                                  0.189097
#
#                                    Advanced Programming.5  Final Project.1
# Prerequisite
# any programming language                         0.552126         0.597492
#  Mathematics for Computer Science                0.552126         0.597492
# C++                                              0.189097         0.341752
#  Java                                            0.189097         0.341752
#  linear algebra                                  0.189097         0.341752
#
# [5 rows x 86 columns]

# %% [markdown]
# # Handling Course Pre-requisites

# %%
df = pd.DataFrame(columns=["Prerequisite"] + list(curr["Courses"]) + list(curr["Topic"]))

# %%
df
# Out:
# Empty DataFrame
# Columns: [Prerequisite, Python for Everybody, Introduction to Computer Science and Programming using Python, How to Code - Simple Data, How to Code - Complex Data, Programming Languages, Part A, Programming Languages, Part B, Programming Languages, Part C, Object-Oriented Design, Design Patterns, Software Architecture, Calculus 1A: Differentiation, Calculus 1B: Integration, Calculus 1C: Coordinate Systems & Infinite Series, Mathematics for Computer Science, The Missing Semester of Your CS Education, Build a Modern Computer from First Principles: From Nand to Tetris, Build a Modern Computer from First Principles: Nand to Tetris Part II, Operating Systems: Three Easy Pieces, Computer Networking: a Top-Down Approach, Divide and Conquer, Sorting and Searching, and Randomized Algorithms, Graph Search, Shortest Paths, and Data Structures, Greedy Algorithms, Minimum Spanning Trees, and Dynamic Programming, Shortest Paths Revisited, NP-Complete Problems and What To Do About Them, Cybersecurity Fundamentals, Principles of Secure Coding, Identifying Security Vulnerabilities, Identifying Security Vulnerabilities in C/C++ Programming or Exploiting and Securing Vulnerabilities in Java Applications, Databases: Modeling and Theory, Databases: Relational Databases and SQL, Databases: Semistructured Data, Machine Learning, Computer Graphics, Software Engineering: Introduction, Ethics, Technology and Engineering, Intellectual Property Law in Digital Age, Data Privacy Fundamentals, Parallel Programming, Compilers, Introduction to Haskell, Learn Prolog Now!, Software Debugging, Software Testing, Final Project, Intro CS, Intro CS, Core Programming, Core Programming, Core Programming, Core Programming, Core Programming, Core Programming, Core Programming, Core Programming, Core Math, Core Math, Core Math, Core Math, CS Tools, Core Systems, Core Systems, Core Systems, Core Systems, Core Theory, Core Theory, Core Theory, Core Theory, Core Security, Core Security, Core Security, Core Security, Core Applications, Core Applications, Core Applications, Core Applications, Core Applications, Core Applications, Core Ethics, Core Ethics, Core Ethics, Advanced Programming, Advanced Programming, Advanced Programming, Advanced Programming, Advanced Programming, Advanced Programming, Final Project]
# Index: []
#
# [0 rows x 87 columns]

# %%
nlp = spacy.load("en_core_web_sm")
for i in set(curr["Prerequisites"]): 
    if str(type(i)) != "<class 'float'>":
        for k in i.split(";"):
            prereq = nlp(i)
            row = {"Prerequisite":k}
            if i in df["Prerequisite"]:
                continue
            for j in list(curr["Courses"]) + list(curr["Topic"]):
                course = nlp(j)
                row[j] = prereq.similarity(course)
            df = df.append(row,ignore_index=True)
# Out:
# C:\Users\mitug\AppData\Local\Temp/ipykernel_17176/3575364071.py:11: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   row[j] = prereq.similarity(course)

# %%
df = df.set_index("Prerequisite")

# %%
df
# Out:
#                                                     Python for Everybody  \
# Prerequisite
# any programming language                                        0.448595
#  Mathematics for Computer Science                               0.448595
# C++                                                             0.281555
#  Java                                                           0.281555
#  linear algebra                                                 0.281555
# Core Programming                                                0.257639
#  a sizable project                                              0.257639
# Programming Languages, Part B                                   0.178415
# -                                                              -0.016595
# Python                                                          0.347913
#  programming experience                                         0.347913
# one of these programming languages                              0.596806
#  From Nand to Tetris Part I                                     0.596806
# algorithms, familiarity with C is useful                        0.558405
# Graph Search, Shortest Paths, and Data Structures               0.199758
# Object-Oriented Design                                          0.180903
# none                                                            0.371155
# Basic Java                                                      0.367313
# Scala programming                                               0.318656
# high school algebra                                             0.369998
# Divide and Conquer, Sorting and Searching, and ...              0.273155
# Python                                                          0.154644
#  object-oriented programming                                    0.154644
# C-like programming language                                     0.177409
# algebra                                                         0.174908
#  probability                                                    0.174908
#  basic CS                                                       0.174908
# Greedy Algorithms, Minimum Spanning Trees, and ...              0.317837
# Calculus 1C                                                     0.267147
# core programming                                                0.295526
# Programming Languages, Part A                                   0.222033
# Design Patterns                                                 0.287245
# Calculus 1A                                                     0.231365
# linear algebra                                                  0.357139
# How to Code: Simple Data                                        0.347886
# high school math                                                0.403973
# Calculus 1B                                                     0.249494
# How to Code (Hear instructor)                                   0.205078
#
#                                                     Introduction to Computer Science and Programming using Python  \
# Prerequisite
# any programming language                                                                     0.595221
#  Mathematics for Computer Science                                                            0.595221
# C++                                                                                          0.212375
#  Java                                                                                        0.212375
#  linear algebra                                                                              0.212375
# Core Programming                                                                             0.266951
#  a sizable project                                                                           0.266951
# Programming Languages, Part B                                                                0.457381
# -                                                                                           -0.165618
# Python                                                                                       0.317743
#  programming experience                                                                      0.317743
# one of these programming languages                                                           0.671858
#  From Nand to Tetris Part I                                                                  0.671858
# algorithms, familiarity with C is useful                                                     0.426478
# Graph Search, Shortest Paths, and Data Structures                                            0.439431
# Object-Oriented Design                                                                       0.282555
# none                                                                                         0.174562
# Basic Java                                                                                   0.319664
# Scala programming                                                                            0.393462
# high school algebra                                                                          0.367067
# Divide and Conquer, Sorting and Searching, and ...                                           0.588041
# Python                                                                                       0.086713
#  object-oriented programming                                                                 0.086713
# C-like programming language                                                                  0.319377
# algebra                                                                                      0.087693
#  probability                                                                                 0.087693
#  basic CS                                                                                    0.087693
# Greedy Algorithms, Minimum Spanning Trees, and ...                                           0.565100
# Calculus 1C                                                                                  0.336377
# core programming                                                                             0.414897
# Programming Languages, Part A                                                                0.469892
# Design Patterns                                                                              0.425374
# Calculus 1A                                                                                  0.262561
# linear algebra                                                                               0.351271
# How to Code: Simple Data                                                                     0.349117
# high school math                                                                             0.420308
# Calculus 1B                                                                                  0.275276
# How to Code (Hear instructor)                                                                0.322210
#
#                                                     How to Code - Simple Data  \
# Prerequisite
# any programming language                                             0.441982
#  Mathematics for Computer Science                                    0.441982
# C++                                                                  0.319161
#  Java                                                                0.319161
#  linear algebra                                                      0.319161
# Core Programming                                                     0.386797
#  a sizable project                                                   0.386797
# Programming Languages, Part B                                        0.534867
# -                                                                    0.104927
# Python                                                               0.325370
#  programming experience                                              0.325370
# one of these programming languages                                   0.450320
#  From Nand to Tetris Part I                                          0.450320
# algorithms, familiarity with C is useful                             0.109691
# Graph Search, Shortest Paths, and Data Structures                    0.405153
# Object-Oriented Design                                               0.539156
# none                                                                -0.010171
# Basic Java                                                           0.430784
# Scala programming                                                    0.390387
# high school algebra                                                  0.441401
# Divide and Conquer, Sorting and Searching, and ...                   0.252149
# Python                                                               0.378811
#  object-oriented programming                                         0.378811
# C-like programming language                                          0.474505
# algebra                                                              0.172141
#  probability                                                         0.172141
#  basic CS                                                            0.172141
# Greedy Algorithms, Minimum Spanning Trees, and ...                   0.484041
# Calculus 1C                                                          0.184690
# core programming                                                     0.451572
# Programming Languages, Part A                                        0.495084
# Design Patterns                                                      0.542261
# Calculus 1A                                                          0.195591
# linear algebra                                                       0.371926
# How to Code: Simple Data                                             0.747667
# high school math                                                     0.415324
# Calculus 1B                                                          0.256802
# How to Code (Hear instructor)                                        0.644563
#
#                                                     How to Code - Complex Data  \
# Prerequisite
# any programming language                                              0.499089
#  Mathematics for Computer Science                                     0.499089
# C++                                                                   0.284144
#  Java                                                                 0.284144
#  linear algebra                                                       0.284144
# Core Programming                                                      0.395833
#  a sizable project                                                    0.395833
# Programming Languages, Part B                                         0.572722
# -                                                                     0.105341
# Python                                                                0.327442
#  programming experience                                               0.327442
# one of these programming languages                                    0.456364
#  From Nand to Tetris Part I                                           0.456364
# algorithms, familiarity with C is useful                              0.102018
# Graph Search, Shortest Paths, and Data Structures                     0.447512
# Object-Oriented Design                                                0.562732
# none                                                                 -0.000726
# Basic Java                                                            0.441584
# Scala programming                                                     0.396083
# high school algebra                                                   0.427629
# Divide and Conquer, Sorting and Searching, and ...                    0.278759
# Python                                                                0.359073
#  object-oriented programming                                          0.359073
# C-like programming language                                           0.485193
# algebra                                                               0.150106
#  probability                                                          0.150106
#  basic CS                                                             0.150106
# Greedy Algorithms, Minimum Spanning Trees, and ...                    0.493570
# Calculus 1C                                                           0.192065
# core programming                                                      0.494446
# Programming Languages, Part A                                         0.541755
# Design Patterns                                                       0.592321
# Calculus 1A                                                           0.187476
# linear algebra                                                        0.344008
# How to Code: Simple Data                                              0.712122
# high school math                                                      0.433975
# Calculus 1B                                                           0.261892
# How to Code (Hear instructor)                                         0.594462
#
#                                                     Programming Languages, Part A  \
# Prerequisite
# any programming language                                                 0.660203
#  Mathematics for Computer Science                                        0.660203
# C++                                                                      0.507478
#  Java                                                                    0.507478
#  linear algebra                                                          0.507478
# Core Programming                                                         0.621010
#  a sizable project                                                       0.621010
# Programming Languages, Part B                                            0.971706
# -                                                                        0.076003
# Python                                                                   0.481084
#  programming experience                                                  0.481084
# one of these programming languages                                       0.516684
#  From Nand to Tetris Part I                                              0.516684
# algorithms, familiarity with C is useful                                 0.345746
# Graph Search, Shortest Paths, and Data Structures                        0.746227
# Object-Oriented Design                                                   0.320771
# none                                                                     0.084616
# Basic Java                                                               0.469216
# Scala programming                                                        0.405918
# high school algebra                                                      0.333702
# Divide and Conquer, Sorting and Searching, and ...                       0.472740
# Python                                                                   0.263978
#  object-oriented programming                                             0.263978
# C-like programming language                                              0.373188
# algebra                                                                  0.422171
#  probability                                                             0.422171
#  basic CS                                                                0.422171
# Greedy Algorithms, Minimum Spanning Trees, and ...                       0.757319
# Calculus 1C                                                              0.369557
# core programming                                                         0.500160
# Programming Languages, Part A                                            1.000000
# Design Patterns                                                          0.597610
# Calculus 1A                                                              0.312461
# linear algebra                                                           0.384770
# How to Code: Simple Data                                                 0.480058
# high school math                                                         0.330798
# Calculus 1B                                                              0.373580
# How to Code (Hear instructor)                                            0.330451
#
#                                                     Programming Languages, Part B  \
# Prerequisite
# any programming language                                                 0.659250
#  Mathematics for Computer Science                                        0.659250
# C++                                                                      0.478266
#  Java                                                                    0.478266
#  linear algebra                                                          0.478266
# Core Programming                                                         0.617710
#  a sizable project                                                       0.617710
# Programming Languages, Part B                                            1.000000
# -                                                                        0.024623
# Python                                                                   0.484616
#  programming experience                                                  0.484616
# one of these programming languages                                       0.488572
#  From Nand to Tetris Part I                                              0.488572
# algorithms, familiarity with C is useful                                 0.337164
# Graph Search, Shortest Paths, and Data Structures                        0.771709
# Object-Oriented Design                                                   0.366587
# none                                                                     0.035105
# Basic Java                                                               0.459544
# Scala programming                                                        0.372187
# high school algebra                                                      0.357487
# Divide and Conquer, Sorting and Searching, and ...                       0.468771
# Python                                                                   0.296367
#  object-oriented programming                                             0.296367
# C-like programming language                                              0.380876
# algebra                                                                  0.411802
#  probability                                                             0.411802
#  basic CS                                                                0.411802
# Greedy Algorithms, Minimum Spanning Trees, and ...                       0.780163
# Calculus 1C                                                              0.263268
# core programming                                                         0.514064
# Programming Languages, Part A                                            0.971706
# Design Patterns                                                          0.609751
# Calculus 1A                                                              0.203636
# linear algebra                                                           0.358625
# How to Code: Simple Data                                                 0.480928
# high school math                                                         0.345230
# Calculus 1B                                                              0.287892
# How to Code (Hear instructor)                                            0.345506
#
#                                                     Programming Languages, Part C  \
# Prerequisite
# any programming language                                                 0.644460
#  Mathematics for Computer Science                                        0.644460
# C++                                                                      0.528526
#  Java                                                                    0.528526
#  linear algebra                                                          0.528526
# Core Programming                                                         0.620246
#  a sizable project                                                       0.620246
# Programming Languages, Part B                                            0.959208
# -                                                                        0.073966
# Python                                                                   0.528703
#  programming experience                                                  0.528703
# one of these programming languages                                       0.480687
#  From Nand to Tetris Part I                                              0.480687
# algorithms, familiarity with C is useful                                 0.364690
# Graph Search, Shortest Paths, and Data Structures                        0.731581
# Object-Oriented Design                                                   0.315625
# none                                                                     0.129428
# Basic Java                                                               0.487635
# Scala programming                                                        0.454020
# high school algebra                                                      0.348972
# Divide and Conquer, Sorting and Searching, and ...                       0.455273
# Python                                                                   0.273802
#  object-oriented programming                                             0.273802
# C-like programming language                                              0.363810
# algebra                                                                  0.453776
#  probability                                                             0.453776
#  basic CS                                                                0.453776
# Greedy Algorithms, Minimum Spanning Trees, and ...                       0.740271
# Calculus 1C                                                              0.369966
# core programming                                                         0.540367
# Programming Languages, Part A                                            0.973385
# Design Patterns                                                          0.611061
# Calculus 1A                                                              0.316684
# linear algebra                                                           0.415183
# How to Code: Simple Data                                                 0.519834
# high school math                                                         0.334697
# Calculus 1B                                                              0.367686
# How to Code (Hear instructor)                                            0.351912
#
#                                                     Object-Oriented Design  \
# Prerequisite
# any programming language                                          0.406581
#  Mathematics for Computer Science                                 0.406581
# C++                                                               0.074031
#  Java                                                             0.074031
#  linear algebra                                                   0.074031
# Core Programming                                                  0.401957
#  a sizable project                                                0.401957
# Programming Languages, Part B                                     0.366587
# -                                                                 0.159847
# Python                                                            0.279880
#  programming experience                                           0.279880
# one of these programming languages                                0.222679
#  From Nand to Tetris Part I                                       0.222679
# algorithms, familiarity with C is useful                          0.127458
# Graph Search, Shortest Paths, and Data Structures                 0.260483
# Object-Oriented Design                                            1.000000
# none                                                              0.114950
# Basic Java                                                        0.357415
# Scala programming                                                 0.349700
# high school algebra                                               0.357612
# Divide and Conquer, Sorting and Searching, and ...                0.121523
# Python                                                            0.746800
#  object-oriented programming                                      0.746800
# C-like programming language                                       0.644201
# algebra                                                           0.139021
#  probability                                                      0.139021
#  basic CS                                                         0.139021
# Greedy Algorithms, Minimum Spanning Trees, and ...                0.380509
# Calculus 1C                                                       0.212190
# core programming                                                  0.516078
# Programming Languages, Part A                                     0.320771
# Design Patterns                                                   0.428648
# Calculus 1A                                                       0.144788
# linear algebra                                                    0.124882
# How to Code: Simple Data                                          0.211499
# high school math                                                  0.475066
# Calculus 1B                                                       0.312206
# How to Code (Hear instructor)                                     0.258504
#
#                                                     Design Patterns  \
# Prerequisite
# any programming language                                   0.524441
#  Mathematics for Computer Science                          0.524441
# C++                                                        0.293981
#  Java                                                      0.293981
#  linear algebra                                            0.293981
# Core Programming                                           0.533186
#  a sizable project                                         0.533186
# Programming Languages, Part B                              0.609751
# -                                                         -0.026023
# Python                                                     0.434236
#  programming experience                                    0.434236
# one of these programming languages                         0.439477
#  From Nand to Tetris Part I                                0.439477
# algorithms, familiarity with C is useful                   0.221948
# Graph Search, Shortest Paths, and Data Structures          0.539957
# Object-Oriented Design                                     0.428648
# none                                                       0.107711
# Basic Java                                                 0.554388
# Scala programming                                          0.535086
# high school algebra                                        0.490888
# Divide and Conquer, Sorting and Searching, and ...         0.203486
# Python                                                     0.236995
#  object-oriented programming                               0.236995
# C-like programming language                                0.247884
# algebra                                                    0.268074
#  probability                                               0.268074
#  basic CS                                                  0.268074
# Greedy Algorithms, Minimum Spanning Trees, and ...         0.556623
# Calculus 1C                                                0.353053
# core programming                                           0.571787
# Programming Languages, Part A                              0.597610
# Design Patterns                                            1.000000
# Calculus 1A                                                0.288635
# linear algebra                                             0.403055
# How to Code: Simple Data                                   0.517171
# high school math                                           0.471912
# Calculus 1B                                                0.382755
# How to Code (Hear instructor)                              0.291810
#
#                                                     Software Architecture  \
# Prerequisite
# any programming language                                         0.612727
#  Mathematics for Computer Science                                0.612727
# C++                                                              0.356474
#  Java                                                            0.356474
#  linear algebra                                                  0.356474
# Core Programming                                                 0.548459
#  a sizable project                                               0.548459
# Programming Languages, Part B                                    0.622449
# -                                                               -0.014116
# Python                                                           0.527649
#  programming experience                                          0.527649
# one of these programming languages                               0.473123
#  From Nand to Tetris Part I                                      0.473123
# algorithms, familiarity with C is useful                         0.222677
# Graph Search, Shortest Paths, and Data Structures                0.511249
# Object-Oriented Design                                           0.393599
# none                                                             0.270682
# Basic Java                                                       0.643843
# Scala programming                                                0.628143
# high school algebra                                              0.601529
# Divide and Conquer, Sorting and Searching, and ...               0.232653
# Python                                                           0.190344
#  object-oriented programming                                     0.190344
# C-like programming language                                      0.392448
# algebra                                                          0.247215
#  probability                                                     0.247215
#  basic CS                                                        0.247215
# Greedy Algorithms, Minimum Spanning Trees, and ...               0.529377
# Calculus 1C                                                      0.457924
# core programming                                                 0.618759
# Programming Languages, Part A                                    0.623143
# Design Patterns                                                  0.799617
# Calculus 1A                                                      0.396023
# linear algebra                                                   0.523421
# How to Code: Simple Data                                         0.547328
# high school math                                                 0.601750
# Calculus 1B                                                      0.425519
# How to Code (Hear instructor)                                    0.357301
#
#                                                     ...  Core Ethics  \
# Prerequisite                                        ...
# any programming language                            ...     0.519370
#  Mathematics for Computer Science                   ...     0.519370
# C++                                                 ...     0.368729
#  Java                                               ...     0.368729
#  linear algebra                                     ...     0.368729
# Core Programming                                    ...     0.479676
#  a sizable project                                  ...     0.479676
# Programming Languages, Part B                       ...     0.625631
# -                                                   ...     0.004199
# Python                                              ...     0.422428
#  programming experience                             ...     0.422428
# one of these programming languages                  ...     0.499899
#  From Nand to Tetris Part I                         ...     0.499899
# algorithms, familiarity with C is useful            ...     0.176812
# Graph Search, Shortest Paths, and Data Structures   ...     0.544276
# Object-Oriented Design                              ...     0.305170
# none                                                ...     0.102566
# Basic Java                                          ...     0.656815
# Scala programming                                   ...     0.449168
# high school algebra                                 ...     0.468916
# Divide and Conquer, Sorting and Searching, and ...  ...     0.223496
# Python                                              ...     0.141082
#  object-oriented programming                        ...     0.141082
# C-like programming language                         ...     0.263787
# algebra                                             ...     0.254527
#  probability                                        ...     0.254527
#  basic CS                                           ...     0.254527
# Greedy Algorithms, Minimum Spanning Trees, and ...  ...     0.545672
# Calculus 1C                                         ...     0.338223
# core programming                                    ...     0.552095
# Programming Languages, Part A                       ...     0.629293
# Design Patterns                                     ...     0.770301
# Calculus 1A                                         ...     0.391274
# linear algebra                                      ...     0.477316
# How to Code: Simple Data                            ...     0.529959
# high school math                                    ...     0.398829
# Calculus 1B                                         ...     0.420154
# How to Code (Hear instructor)                       ...     0.193053
#
#                                                     Core Ethics.1  \
# Prerequisite
# any programming language                                 0.519370
#  Mathematics for Computer Science                        0.519370
# C++                                                      0.368729
#  Java                                                    0.368729
#  linear algebra                                          0.368729
# Core Programming                                         0.479676
#  a sizable project                                       0.479676
# Programming Languages, Part B                            0.625631
# -                                                        0.004199
# Python                                                   0.422428
#  programming experience                                  0.422428
# one of these programming languages                       0.499899
#  From Nand to Tetris Part I                              0.499899
# algorithms, familiarity with C is useful                 0.176812
# Graph Search, Shortest Paths, and Data Structures        0.544276
# Object-Oriented Design                                   0.305170
# none                                                     0.102566
# Basic Java                                               0.656815
# Scala programming                                        0.449168
# high school algebra                                      0.468916
# Divide and Conquer, Sorting and Searching, and ...       0.223496
# Python                                                   0.141082
#  object-oriented programming                             0.141082
# C-like programming language                              0.263787
# algebra                                                  0.254527
#  probability                                             0.254527
#  basic CS                                                0.254527
# Greedy Algorithms, Minimum Spanning Trees, and ...       0.545672
# Calculus 1C                                              0.338223
# core programming                                         0.552095
# Programming Languages, Part A                            0.629293
# Design Patterns                                          0.770301
# Calculus 1A                                              0.391274
# linear algebra                                           0.477316
# How to Code: Simple Data                                 0.529959
# high school math                                         0.398829
# Calculus 1B                                              0.420154
# How to Code (Hear instructor)                            0.193053
#
#                                                     Core Ethics.2  \
# Prerequisite
# any programming language                                 0.519370
#  Mathematics for Computer Science                        0.519370
# C++                                                      0.368729
#  Java                                                    0.368729
#  linear algebra                                          0.368729
# Core Programming                                         0.479676
#  a sizable project                                       0.479676
# Programming Languages, Part B                            0.625631
# -                                                        0.004199
# Python                                                   0.422428
#  programming experience                                  0.422428
# one of these programming languages                       0.499899
#  From Nand to Tetris Part I                              0.499899
# algorithms, familiarity with C is useful                 0.176812
# Graph Search, Shortest Paths, and Data Structures        0.544276
# Object-Oriented Design                                   0.305170
# none                                                     0.102566
# Basic Java                                               0.656815
# Scala programming                                        0.449168
# high school algebra                                      0.468916
# Divide and Conquer, Sorting and Searching, and ...       0.223496
# Python                                                   0.141082
#  object-oriented programming                             0.141082
# C-like programming language                              0.263787
# algebra                                                  0.254527
#  probability                                             0.254527
#  basic CS                                                0.254527
# Greedy Algorithms, Minimum Spanning Trees, and ...       0.545672
# Calculus 1C                                              0.338223
# core programming                                         0.552095
# Programming Languages, Part A                            0.629293
# Design Patterns                                          0.770301
# Calculus 1A                                              0.391274
# linear algebra                                           0.477316
# How to Code: Simple Data                                 0.529959
# high school math                                         0.398829
# Calculus 1B                                              0.420154
# How to Code (Hear instructor)                            0.193053
#
#                                                     Advanced Programming  \
# Prerequisite
# any programming language                                        0.552126
#  Mathematics for Computer Science                               0.552126
# C++                                                             0.189097
#  Java                                                           0.189097
#  linear algebra                                                 0.189097
# Core Programming                                                0.596768
#  a sizable project                                              0.596768
# Programming Languages, Part B                                   0.543091
# -                                                              -0.102842
# Python                                                          0.433355
#  programming experience                                         0.433355
# one of these programming languages                              0.437491
#  From Nand to Tetris Part I                                     0.437491
# algorithms, familiarity with C is useful                        0.207139
# Graph Search, Shortest Paths, and Data Structures               0.437300
# Object-Oriented Design                                          0.575503
# none                                                            0.141275
# Basic Java                                                      0.719977
# Scala programming                                               0.630369
# high school algebra                                             0.584847
# Divide and Conquer, Sorting and Searching, and ...              0.255723
# Python                                                          0.392725
#  object-oriented programming                                    0.392725
# C-like programming language                                     0.437103
# algebra                                                         0.194201
#  probability                                                    0.194201
#  basic CS                                                       0.194201
# Greedy Algorithms, Minimum Spanning Trees, and ...              0.615110
# Calculus 1C                                                     0.523405
# core programming                                                0.704509
# Programming Languages, Part A                                   0.525773
# Design Patterns                                                 0.632726
# Calculus 1A                                                     0.439087
# linear algebra                                                  0.389536
# How to Code: Simple Data                                        0.410602
# high school math                                                0.596446
# Calculus 1B                                                     0.517604
# How to Code (Hear instructor)                                   0.211603
#
#                                                     Advanced Programming.1  \
# Prerequisite
# any programming language                                          0.552126
#  Mathematics for Computer Science                                 0.552126
# C++                                                               0.189097
#  Java                                                             0.189097
#  linear algebra                                                   0.189097
# Core Programming                                                  0.596768
#  a sizable project                                                0.596768
# Programming Languages, Part B                                     0.543091
# -                                                                -0.102842
# Python                                                            0.433355
#  programming experience                                           0.433355
# one of these programming languages                                0.437491
#  From Nand to Tetris Part I                                       0.437491
# algorithms, familiarity with C is useful                          0.207139
# Graph Search, Shortest Paths, and Data Structures                 0.437300
# Object-Oriented Design                                            0.575503
# none                                                              0.141275
# Basic Java                                                        0.719977
# Scala programming                                                 0.630369
# high school algebra                                               0.584847
# Divide and Conquer, Sorting and Searching, and ...                0.255723
# Python                                                            0.392725
#  object-oriented programming                                      0.392725
# C-like programming language                                       0.437103
# algebra                                                           0.194201
#  probability                                                      0.194201
#  basic CS                                                         0.194201
# Greedy Algorithms, Minimum Spanning Trees, and ...                0.615110
# Calculus 1C                                                       0.523405
# core programming                                                  0.704509
# Programming Languages, Part A                                     0.525773
# Design Patterns                                                   0.632726
# Calculus 1A                                                       0.439087
# linear algebra                                                    0.389536
# How to Code: Simple Data                                          0.410602
# high school math                                                  0.596446
# Calculus 1B                                                       0.517604
# How to Code (Hear instructor)                                     0.211603
#
#                                                     Advanced Programming.2  \
# Prerequisite
# any programming language                                          0.552126
#  Mathematics for Computer Science                                 0.552126
# C++                                                               0.189097
#  Java                                                             0.189097
#  linear algebra                                                   0.189097
# Core Programming                                                  0.596768
#  a sizable project                                                0.596768
# Programming Languages, Part B                                     0.543091
# -                                                                -0.102842
# Python                                                            0.433355
#  programming experience                                           0.433355
# one of these programming languages                                0.437491
#  From Nand to Tetris Part I                                       0.437491
# algorithms, familiarity with C is useful                          0.207139
# Graph Search, Shortest Paths, and Data Structures                 0.437300
# Object-Oriented Design                                            0.575503
# none                                                              0.141275
# Basic Java                                                        0.719977
# Scala programming                                                 0.630369
# high school algebra                                               0.584847
# Divide and Conquer, Sorting and Searching, and ...                0.255723
# Python                                                            0.392725
#  object-oriented programming                                      0.392725
# C-like programming language                                       0.437103
# algebra                                                           0.194201
#  probability                                                      0.194201
#  basic CS                                                         0.194201
# Greedy Algorithms, Minimum Spanning Trees, and ...                0.615110
# Calculus 1C                                                       0.523405
# core programming                                                  0.704509
# Programming Languages, Part A                                     0.525773
# Design Patterns                                                   0.632726
# Calculus 1A                                                       0.439087
# linear algebra                                                    0.389536
# How to Code: Simple Data                                          0.410602
# high school math                                                  0.596446
# Calculus 1B                                                       0.517604
# How to Code (Hear instructor)                                     0.211603
#
#                                                     Advanced Programming.3  \
# Prerequisite
# any programming language                                          0.552126
#  Mathematics for Computer Science                                 0.552126
# C++                                                               0.189097
#  Java                                                             0.189097
#  linear algebra                                                   0.189097
# Core Programming                                                  0.596768
#  a sizable project                                                0.596768
# Programming Languages, Part B                                     0.543091
# -                                                                -0.102842
# Python                                                            0.433355
#  programming experience                                           0.433355
# one of these programming languages                                0.437491
#  From Nand to Tetris Part I                                       0.437491
# algorithms, familiarity with C is useful                          0.207139
# Graph Search, Shortest Paths, and Data Structures                 0.437300
# Object-Oriented Design                                            0.575503
# none                                                              0.141275
# Basic Java                                                        0.719977
# Scala programming                                                 0.630369
# high school algebra                                               0.584847
# Divide and Conquer, Sorting and Searching, and ...                0.255723
# Python                                                            0.392725
#  object-oriented programming                                      0.392725
# C-like programming language                                       0.437103
# algebra                                                           0.194201
#  probability                                                      0.194201
#  basic CS                                                         0.194201
# Greedy Algorithms, Minimum Spanning Trees, and ...                0.615110
# Calculus 1C                                                       0.523405
# core programming                                                  0.704509
# Programming Languages, Part A                                     0.525773
# Design Patterns                                                   0.632726
# Calculus 1A                                                       0.439087
# linear algebra                                                    0.389536
# How to Code: Simple Data                                          0.410602
# high school math                                                  0.596446
# Calculus 1B                                                       0.517604
# How to Code (Hear instructor)                                     0.211603
#
#                                                     Advanced Programming.4  \
# Prerequisite
# any programming language                                          0.552126
#  Mathematics for Computer Science                                 0.552126
# C++                                                               0.189097
#  Java                                                             0.189097
#  linear algebra                                                   0.189097
# Core Programming                                                  0.596768
#  a sizable project                                                0.596768
# Programming Languages, Part B                                     0.543091
# -                                                                -0.102842
# Python                                                            0.433355
#  programming experience                                           0.433355
# one of these programming languages                                0.437491
#  From Nand to Tetris Part I                                       0.437491
# algorithms, familiarity with C is useful                          0.207139
# Graph Search, Shortest Paths, and Data Structures                 0.437300
# Object-Oriented Design                                            0.575503
# none                                                              0.141275
# Basic Java                                                        0.719977
# Scala programming                                                 0.630369
# high school algebra                                               0.584847
# Divide and Conquer, Sorting and Searching, and ...                0.255723
# Python                                                            0.392725
#  object-oriented programming                                      0.392725
# C-like programming language                                       0.437103
# algebra                                                           0.194201
#  probability                                                      0.194201
#  basic CS                                                         0.194201
# Greedy Algorithms, Minimum Spanning Trees, and ...                0.615110
# Calculus 1C                                                       0.523405
# core programming                                                  0.704509
# Programming Languages, Part A                                     0.525773
# Design Patterns                                                   0.632726
# Calculus 1A                                                       0.439087
# linear algebra                                                    0.389536
# How to Code: Simple Data                                          0.410602
# high school math                                                  0.596446
# Calculus 1B                                                       0.517604
# How to Code (Hear instructor)                                     0.211603
#
#                                                     Advanced Programming.5  \
# Prerequisite
# any programming language                                          0.552126
#  Mathematics for Computer Science                                 0.552126
# C++                                                               0.189097
#  Java                                                             0.189097
#  linear algebra                                                   0.189097
# Core Programming                                                  0.596768
#  a sizable project                                                0.596768
# Programming Languages, Part B                                     0.543091
# -                                                                -0.102842
# Python                                                            0.433355
#  programming experience                                           0.433355
# one of these programming languages                                0.437491
#  From Nand to Tetris Part I                                       0.437491
# algorithms, familiarity with C is useful                          0.207139
# Graph Search, Shortest Paths, and Data Structures                 0.437300
# Object-Oriented Design                                            0.575503
# none                                                              0.141275
# Basic Java                                                        0.719977
# Scala programming                                                 0.630369
# high school algebra                                               0.584847
# Divide and Conquer, Sorting and Searching, and ...                0.255723
# Python                                                            0.392725
#  object-oriented programming                                      0.392725
# C-like programming language                                       0.437103
# algebra                                                           0.194201
#  probability                                                      0.194201
#  basic CS                                                         0.194201
# Greedy Algorithms, Minimum Spanning Trees, and ...                0.615110
# Calculus 1C                                                       0.523405
# core programming                                                  0.704509
# Programming Languages, Part A                                     0.525773
# Design Patterns                                                   0.632726
# Calculus 1A                                                       0.439087
# linear algebra                                                    0.389536
# How to Code: Simple Data                                          0.410602
# high school math                                                  0.596446
# Calculus 1B                                                       0.517604
# How to Code (Hear instructor)                                     0.211603
#
#                                                     Final Project.1
# Prerequisite
# any programming language                                   0.597492
#  Mathematics for Computer Science                          0.597492
# C++                                                        0.341752
#  Java                                                      0.341752
#  linear algebra                                            0.341752
# Core Programming                                           0.604241
#  a sizable project                                         0.604241
# Programming Languages, Part B                              0.523993
# -                                                         -0.053804
# Python                                                     0.501069
#  programming experience                                    0.501069
# one of these programming languages                         0.507735
#  From Nand to Tetris Part I                                0.507735
# algorithms, familiarity with C is useful                   0.303739
# Graph Search, Shortest Paths, and Data Structures          0.420396
# Object-Oriented Design                                     0.405703
# none                                                       0.163858
# Basic Java                                                 0.711622
# Scala programming                                          0.620747
# high school algebra                                        0.549081
# Divide and Conquer, Sorting and Searching, and ...         0.279146
# Python                                                     0.243236
#  object-oriented programming                               0.243236
# C-like programming language                                0.459555
# algebra                                                    0.306929
#  probability                                               0.306929
#  basic CS                                                  0.306929
# Greedy Algorithms, Minimum Spanning Trees, and ...         0.531833
# Calculus 1C                                                0.570529
# core programming                                           0.595079
# Programming Languages, Part A                              0.546642
# Design Patterns                                            0.641763
# Calculus 1A                                                0.530801
# linear algebra                                             0.483139
# How to Code: Simple Data                                   0.510676
# high school math                                           0.553758
# Calculus 1B                                                0.616060
# How to Code (Hear instructor)                              0.238522
#
# [38 rows x 86 columns]

# %%
def get_most_relevant_course(row):
    best_similarity = max(row[1:])
    cols = list(df.columns)
    i = list(row[1:]).index(best_similarity)
    #print(row[0],"\t",cols[i + 1],"\t",best_similarity)
    if best_similarity > 0.7:
        return {"Pre":row[0],"Rel":cols[i + 1],"simi":best_similarity,"incorrect":None}
    else:
        return {"Pre":row[0],"Rel":None,"simi":best_similarity,"incorrect":cols[i+1]}

# %%
d = pd.DataFrame(columns=["Pre","Rel","simi","incorrect"])

# %%
for i in df.apply(get_most_relevant_course,axis=1):
    d = d.append(i, ignore_index=True)

# %%
d
# Out:
#                                                   Pre  \
# 0                            any programming language
# 1                    Mathematics for Computer Science
# 2                                                 C++
# 3                                                Java
# 4                                      linear algebra
# 5                                    Core Programming
# 6                                   a sizable project
# 7                       Programming Languages, Part B
# 8                                                   -
# 9                                              Python
# 10                             programming experience
# 11                 one of these programming languages
# 12                         From Nand to Tetris Part I
# 13           algorithms, familiarity with C is useful
# 14  Graph Search, Shortest Paths, and Data Structures
# 15                             Object-Oriented Design
# 16                                               none
# 17                                         Basic Java
# 18                                  Scala programming
# 19                                high school algebra
# 20  Divide and Conquer, Sorting and Searching, and...
# 21                                             Python
# 22                        object-oriented programming
# 23                        C-like programming language
# 24                                            algebra
# 25                                        probability
# 26                                           basic CS
# 27  Greedy Algorithms, Minimum Spanning Trees, and...
# 28                                        Calculus 1C
# 29                                   core programming
# 30                      Programming Languages, Part A
# 31                                    Design Patterns
# 32                                        Calculus 1A
# 33                                     linear algebra
# 34                           How to Code: Simple Data
# 35                                   high school math
# 36                                        Calculus 1B
# 37                      How to Code (Hear instructor)
#
#                                                   Rel      simi  \
# 0                    Mathematics for Computer Science  0.747416
# 1                    Mathematics for Computer Science  0.747416
# 2                                                None  0.645275
# 3                                                None  0.645275
# 4                                                None  0.645275
# 5                                                None  0.666442
# 6                                                None  0.666442
# 7                       Programming Languages, Part B  1.000000
# 8                                                None  0.228649
# 9                                                None  0.673510
# 10                                               None  0.673510
# 11  Build a Modern Computer from First Principles:...  0.764181
# 12  Build a Modern Computer from First Principles:...  0.764181
# 13                                               None  0.558405
# 14  Graph Search, Shortest Paths, and Data Structures  1.000000
# 15                             Object-Oriented Design  1.000000
# 16                                               None  0.371956
# 17                               Advanced Programming  0.719977
# 18                                   Core Programming  0.759367
# 19                                               None  0.601529
# 20  Divide and Conquer, Sorting and Searching, and...  1.000000
# 21                             Object-Oriented Design  0.746800
# 22                             Object-Oriented Design  0.746800
# 23                                               None  0.644201
# 24                                               None  0.669152
# 25                                               None  0.669152
# 26                                               None  0.669152
# 27  Greedy Algorithms, Minimum Spanning Trees, and...  1.000000
# 28                       Calculus 1A: Differentiation  0.743040
# 29                                   Core Programming  0.765363
# 30                      Programming Languages, Part A  1.000000
# 31                                    Design Patterns  1.000000
# 32                       Calculus 1A: Differentiation  0.760565
# 33                                               None  0.558168
# 34                          How to Code - Simple Data  0.747667
# 35                                               None  0.670473
# 36                           Calculus 1B: Integration  0.761860
# 37                                               None  0.644563
#
#                                    incorrect
# 0                                       None
# 1                                       None
# 2    Databases: Relational Databases and SQL
# 3    Databases: Relational Databases and SQL
# 4    Databases: Relational Databases and SQL
# 5   Computer Networking: a Top-Down Approach
# 6   Computer Networking: a Top-Down Approach
# 7                                       None
# 8   Computer Networking: a Top-Down Approach
# 9         Software Engineering: Introduction
# 10        Software Engineering: Introduction
# 11                                      None
# 12                                      None
# 13                      Python for Everybody
# 14                                      None
# 15                                      None
# 16                        Software Debugging
# 17                                      None
# 18                                      None
# 19                     Software Architecture
# 20                                      None
# 21                                      None
# 22                                      None
# 23                    Object-Oriented Design
# 24            Databases: Semistructured Data
# 25            Databases: Semistructured Data
# 26            Databases: Semistructured Data
# 27                                      None
# 28                                      None
# 29                                      None
# 30                                      None
# 31                                      None
# 32                                      None
# 33                                  Intro CS
# 34                                      None
# 35                        Software Debugging
# 36                                      None
# 37                 How to Code - Simple Data
